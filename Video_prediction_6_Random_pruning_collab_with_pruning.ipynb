# %% [markdown]
# <a href="https://colab.research.google.com/github/jhchang/DFDC/blob/main/Video_prediction_6_Random_pruning_collab_with_pruning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Video Face Manipulation Detection Through Ensemble of CNNs
# Image and Sound Processing Lab - Politecnico di Milano
# - Nicolò Bonettini
# - Edoardo Daniele Cannas
# - Sara Mandelli
# - Luca Bondi
# - Paolo Bestagini

# %% [markdown]
# # https://github.com/pytorch/tutorials/issues/1054#issuecomment-657991827
# # https://adeshpande3.github.io/A-Beginner%27s-Guide-To-Understanding-Convolutional-Neural-Networks/

# %%
# !git clone https://github.com/polimi-ispl/icpr2020dfdc
# !pip install efficientnet-pytorch
# !pip install -U git+https://github.com/albu/albumentations > /dev/null
# %cd icpr2020dfdc/notebook
# Out:
# Cloning into 'icpr2020dfdc'...
# remote: Enumerating objects: 616, done.
# remote: Counting objects: 100% (616/616), done.
# remote: Compressing objects: 100% (535/535), done.
# remote: Total 616 (delta 318), reused 322 (delta 49), pack-reused 0
# Receiving objects: 100% (616/616), 68.57 MiB | 21.87 MiB/s, done.
# Resolving deltas: 100% (318/318), done.
# Collecting efficientnet-pytorch
#   Downloading https://files.pythonhosted.org/packages/2e/a0/dd40b50aebf0028054b6b35062948da01123d7be38d08b6b1e5435df6363/efficientnet_pytorch-0.7.1.tar.gz
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet-pytorch) (1.8.1+cu101)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch) (1.19.5)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-cp37-none-any.whl size=16443 sha256=91bbfdc77941b3ff0b1afa3b453bf179d4aa34f571558a57595617345d23702f
#   Stored in directory: /root/.cache/pip/wheels/84/27/aa/c46d23c4e8cc72d41283862b1437e0b3ad318417e8ed7d5921
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.7.1
#   Running command git clone -q https://github.com/albu/albumentations /tmp/pip-req-build-c7oq9ldx
# /content/icpr2020dfdc/notebook

# %%
import torch
from torch.utils.model_zoo import load_url
import matplotlib.pyplot as plt
from scipy.special import expit

import sys
sys.path.append('..')

from blazeface import FaceExtractor, BlazeFace, VideoReader
from architectures import fornet,weights
from isplutils import utils

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content/icpr2020dfdc/notebook

# %%
import os
from getpass import getpass
import copy
import random
import numpy as np
import time
from torch import nn
import torch.nn.utils.prune as prune
import torch.nn.functional as F
from itertools import combinations
from pprint import pprint
import json
import csv
import datetime
from sklearn.model_selection import KFold
from functools import lru_cache
import pandas as pd
import io
from contextlib import redirect_stdout
from torchsummary import summary
import pickle

# %%
# !pip install mlflow --quiet
# import mlflow

# os.environ['MLFLOW_TRACKING_USERNAME'] = 'jhchang'
# os.environ['MLFLOW_TRACKING_PASSWORD'] = getpass('Enter your DAGsHub access token: ')
# os.environ['MLFLOW_TRACKING_PROJECTNAME'] = 'DFDC_results'

# mlflow.set_tracking_uri(f'https://dagshub.com/' + os.environ['MLFLOW_TRACKING_USERNAME'] + '/' + os.environ['MLFLOW_TRACKING_PROJECTNAME'] + '.mlflow')

# %%
video_list = os.listdir('/content/drive/MyDrive/cs274/project_datasets/deepfake-detection-challenge/train_sample_videos/')
video_list = video_list[0:20]
print(video_list)
# video_list = os.listdir('/content/drive/MyDrive/cs274/test_videos/')
# Out:
# ['acxwigylke.mp4', 'abqwwspghj.mp4', 'adylbeequz.mp4', 'adohikbdaz.mp4', 'adhsbajydo.mp4', 'abofeumbvv.mp4', 'abarnvbtwb.mp4', 'acqfdwsrhi.mp4', 'aagfhgtpmv.mp4', 'aelzhcnwgf.mp4', 'aelfnikyqj.mp4', 'aapnvogymq.mp4', 'acifjvzvpm.mp4', 'acxnxvbsxk.mp4', 'aczrgyricp.mp4', 'akzbnazxtz.mp4', 'ahqqqilsxt.mp4', 'ahfazfbntc.mp4', 'agqphdxmwt.mp4', 'agrmhtjdlk.mp4']

# %%
try:
    video_list.remove('metadata.json')
except:
    pass

# %%
# # video_list
# kf = KFold(n_splits=5)
# test_folds = []

# video_list = np.array(video_list)

# for _, test_index in kf.split(video_list):
#     print("TEST:", test_index)
#     test_folds.append(video_list[test_index])

# pprint(test_folds)

# %%
json_truth_dict = {}
with open('/content/drive/MyDrive/cs274/project_datasets/deepfake-detection-challenge/train_sample_videos/metadata.json') as json_file:
# with open('/content/drive/MyDrive/cs274/test_videos/metadata.json') as json_file:
    json_truth_dict = json.load(json_file)
# pprint(json_truth_dict)

# %% [markdown]
# ## Parameters

# %%
"""
Choose an architecture between
- EfficientNetB4
- EfficientNetB4ST
- EfficientNetAutoAttB4
- EfficientNetAutoAttB4ST
- Xception
"""
net_model = 'EfficientNetAutoAttB4'

"""
Choose a training dataset between
- DFDC
- FFPP
"""
train_db = 'DFDC'

# %%
device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')
face_policy = 'scale'
face_size = 224
frames_per_video = 32

# %% [markdown]
# ## Initialization

# %%
model_url = weights.weight_url['{:s}_{:s}'.format(net_model,train_db)]
net = getattr(fornet,net_model)().eval().to(device)
state_dict = torch.load('/content/drive/MyDrive/cs274/EfficientNetAutoAttB4_DFDC_bestval-72ed969b2a395fffe11a0d5bf0a635e7260ba2588c28683630d97ff7153389fc.pth')
net.load_state_dict(state_dict)
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b4-6ed6700e.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b4-6ed6700e.pth
# HBox(children=(FloatProgress(value=0.0, max=77999237.0), HTML(value='')))
# Loaded pretrained weights for efficientnet-b4
# <All keys matched successfully>

# %%
# print(list(net.modules()))

# %%
type(next(net.modules()))
# Out:
# architectures.fornet.EfficientNetAutoAttB4

# %%
# save base unpruned model
net_orig = copy.deepcopy(net)

# %%
parameters_to_prune = [
    (module, name) 
    for name, module in dict(net.named_modules()).items()
]

params_to_prune_names = []
pruneable_stuff = []
count = 0
for module, name in parameters_to_prune:
    try:
        for layer_type in ['weight', 'bias']:
            prune.global_unstructured([[module, layer_type]], pruning_method=prune.L1Unstructured, amount=0.3)
            params_to_prune_names.append(f"{name}-{layer_type}")
            pruneable_stuff.append([name, layer_type])

    except:
        count += 1
        pass

print("count " + str(count))
print(len(pruneable_stuff))
# Out:
# count 326
# 420

# %%
print(params_to_prune_names)
# Out:
# ['efficientnet._conv_stem-weight', 'efficientnet._bn0-weight', 'efficientnet._bn0-bias', 'efficientnet._blocks.0._depthwise_conv-weight', 'efficientnet._blocks.0._bn1-weight', 'efficientnet._blocks.0._bn1-bias', 'efficientnet._blocks.0._se_reduce-weight', 'efficientnet._blocks.0._se_reduce-bias', 'efficientnet._blocks.0._se_expand-weight', 'efficientnet._blocks.0._se_expand-bias', 'efficientnet._blocks.0._project_conv-weight', 'efficientnet._blocks.0._bn2-weight', 'efficientnet._blocks.0._bn2-bias', 'efficientnet._blocks.1._depthwise_conv-weight', 'efficientnet._blocks.1._bn1-weight', 'efficientnet._blocks.1._bn1-bias', 'efficientnet._blocks.1._se_reduce-weight', 'efficientnet._blocks.1._se_reduce-bias', 'efficientnet._blocks.1._se_expand-weight', 'efficientnet._blocks.1._se_expand-bias', 'efficientnet._blocks.1._project_conv-weight', 'efficientnet._blocks.1._bn2-weight', 'efficientnet._blocks.1._bn2-bias', 'efficientnet._blocks.2._expand_conv-weight', 'efficientnet._blocks.2._bn0-weight', 'efficientnet._blocks.2._bn0-bias', 'efficientnet._blocks.2._depthwise_conv-weight', 'efficientnet._blocks.2._bn1-weight', 'efficientnet._blocks.2._bn1-bias', 'efficientnet._blocks.2._se_reduce-weight', 'efficientnet._blocks.2._se_reduce-bias', 'efficientnet._blocks.2._se_expand-weight', 'efficientnet._blocks.2._se_expand-bias', 'efficientnet._blocks.2._project_conv-weight', 'efficientnet._blocks.2._bn2-weight', 'efficientnet._blocks.2._bn2-bias', 'efficientnet._blocks.3._expand_conv-weight', 'efficientnet._blocks.3._bn0-weight', 'efficientnet._blocks.3._bn0-bias', 'efficientnet._blocks.3._depthwise_conv-weight', 'efficientnet._blocks.3._bn1-weight', 'efficientnet._blocks.3._bn1-bias', 'efficientnet._blocks.3._se_reduce-weight', 'efficientnet._blocks.3._se_reduce-bias', 'efficientnet._blocks.3._se_expand-weight', 'efficientnet._blocks.3._se_expand-bias', 'efficientnet._blocks.3._project_conv-weight', 'efficientnet._blocks.3._bn2-weight', 'efficientnet._blocks.3._bn2-bias', 'efficientnet._blocks.4._expand_conv-weight', 'efficientnet._blocks.4._bn0-weight', 'efficientnet._blocks.4._bn0-bias', 'efficientnet._blocks.4._depthwise_conv-weight', 'efficientnet._blocks.4._bn1-weight', 'efficientnet._blocks.4._bn1-bias', 'efficientnet._blocks.4._se_reduce-weight', 'efficientnet._blocks.4._se_reduce-bias', 'efficientnet._blocks.4._se_expand-weight', 'efficientnet._blocks.4._se_expand-bias', 'efficientnet._blocks.4._project_conv-weight', 'efficientnet._blocks.4._bn2-weight', 'efficientnet._blocks.4._bn2-bias', 'efficientnet._blocks.5._expand_conv-weight', 'efficientnet._blocks.5._bn0-weight', 'efficientnet._blocks.5._bn0-bias', 'efficientnet._blocks.5._depthwise_conv-weight', 'efficientnet._blocks.5._bn1-weight', 'efficientnet._blocks.5._bn1-bias', 'efficientnet._blocks.5._se_reduce-weight', 'efficientnet._blocks.5._se_reduce-bias', 'efficientnet._blocks.5._se_expand-weight', 'efficientnet._blocks.5._se_expand-bias', 'efficientnet._blocks.5._project_conv-weight', 'efficientnet._blocks.5._bn2-weight', 'efficientnet._blocks.5._bn2-bias', 'efficientnet._blocks.6._expand_conv-weight', 'efficientnet._blocks.6._bn0-weight', 'efficientnet._blocks.6._bn0-bias', 'efficientnet._blocks.6._depthwise_conv-weight', 'efficientnet._blocks.6._bn1-weight', 'efficientnet._blocks.6._bn1-bias', 'efficientnet._blocks.6._se_reduce-weight', 'efficientnet._blocks.6._se_reduce-bias', 'efficientnet._blocks.6._se_expand-weight', 'efficientnet._blocks.6._se_expand-bias', 'efficientnet._blocks.6._project_conv-weight', 'efficientnet._blocks.6._bn2-weight', 'efficientnet._blocks.6._bn2-bias', 'efficientnet._blocks.7._expand_conv-weight', 'efficientnet._blocks.7._bn0-weight', 'efficientnet._blocks.7._bn0-bias', 'efficientnet._blocks.7._depthwise_conv-weight', 'efficientnet._blocks.7._bn1-weight', 'efficientnet._blocks.7._bn1-bias', 'efficientnet._blocks.7._se_reduce-weight', 'efficientnet._blocks.7._se_reduce-bias', 'efficientnet._blocks.7._se_expand-weight', 'efficientnet._blocks.7._s ...

# %%
# create random permutation of indexes and make a chart of which prune
# yield the best results
# good_params_to_prune_names_comb = list(combinations(good_params_to_prune_names, 2))
# pruneable_stuff_comb = list(combinations(pruneable_stuff, 2))
# pruneable_stuff_comb_randslice = random.sample(range(2, 420), 10)
# print(np.array(good_params_to_prune_names_comb))

# %%
prune_percent_pipline = [.80, .70, .60, .50, .40, .30, .20]
param_pipline = [420, 380, 340, 300, 260, 220, 180, 120, 80, 60, 20]
pruneable_stuff_comb_randslice_tail = np.repeat(np.array(param_pipline), len(prune_percent_pipline)).tolist()
pruneable_stuff_comb_randslice = [0] + pruneable_stuff_comb_randslice_tail
prune_percent = [0] + [.80, .70, .60, .50, .40, .30, .20] * len(param_pipline)
# pruneable_stuff_comb_randslice = [0, 1]
# prune_percent = [0, .95]
# pruneable_stuff_comb_randslice = [0, 420, 420]
# prune_percent = [0, .40, .40]
# pruneable_stuff_comb_randslice
print(len(pruneable_stuff_comb_randslice))
print(len(prune_percent))
# Out:
# 78
# 78

# %%
random.seed(376)

results = []
column_names = ['pruning_type', 'num_params', 'percentage_pruned', 'accuracy', 'runtime', 'num_videos','num_similar_params', 
                    'total_possible_selected_paramters', 'new_model_size_mb', 'percentage_of_size_saved']
# column_names = ['num_params', 'percentage_pruned', 'accuracy', 'runtime']


pruning_type = 'global_L1unstructured'

now = datetime.datetime.now()
timestamp = str(now.strftime("%m-%d-%Y_%H:%M:%S"))

base_model = True

transf = utils.get_transformer(face_policy, face_size, net.get_normalizer(), train=False)

facedet = BlazeFace().to(device)
facedet.load_weights("../blazeface/blazeface.pth")
facedet.load_anchors("../blazeface/anchors.npy")
videoreader = VideoReader(verbose=False)
video_read_fn = lambda x: videoreader.read_frames(x, num_frames=frames_per_video)
face_extractor = FaceExtractor(video_read_fn=video_read_fn,facedet=facedet)


@lru_cache(maxsize=200)
def get_face(filename):
    vid_faces = face_extractor.process_video('/content/drive/MyDrive/cs274/project_datasets/deepfake-detection-challenge/train_sample_videos/'+ file_name)
    # vid_faces = face_extractor.process_video('/content/drive/MyDrive/cs274/test_videos/'+ file_name)
    return vid_faces

# mlflow.set_experiment("Pruning Model Statistics")

for num_params, prune_p in zip(pruneable_stuff_comb_randslice, prune_percent):
    current_run_module_names_list = []

    pruneable_stuff_comb_pair = random.sample(pruneable_stuff, num_params)

    # print(f'len(pruneable_stuff_comb_pair): {len(pruneable_stuff_comb_pair)}')
    # print(f'len(pruneable_stuff): {len(pruneable_stuff)}')


    # reset the model
    net = copy.deepcopy(net_orig)

    module_list = [
        (module, name) 
        for name, module in dict(net.named_modules()).items()
    ]

    if (not base_model):
        prun_list = []
        current_run_module_names_list = []
        for module, name in module_list:
            for name_target_module in pruneable_stuff_comb_pair:
            # for name_target_module in pruneable_stuff:
                if name == name_target_module[0]:
                    current_run_module_names_list.append(f'{name}_{name_target_module[1]}')
                    prun_list.append([module, name_target_module[1]])
            
        print('# of modules to be pruned: {}'.format(len(current_run_module_names_list)))
        print('% of each module pruned: {}'.format(prune_p))

        # for i in current_run_module_names_list:
        #     param_dict[i] = 0.2

        # print(f'len(prun_list): {len(prun_list)}')
        preprune = []
        pre_count = 0
        for p in prun_list:
            if p[1] == 'weight':
                if p[0].weight != None:
                    temp = np.ravel(p[0].weight.cpu().detach().numpy()).tolist()
                    # print(f"length appended to preprune: {len(temp)}")
                    preprune.extend(temp)
                    pre_count += 1
                else:
                    pass
            elif p[1] == 'bias':
                if p[0].bias != None:
                    temp = np.ravel(p[0].bias.cpu().detach().numpy()).tolist()
                    # print(f"length appended to preprune: {len(temp)}")
                    preprune.extend(temp)
                    pre_count += 1
                else:
                    pass

        # print(f'preprune: {preprune}')
        # print(f'preprune.ndim: {preprune.ndim}')
        preprune = np.ravel(preprune).astype(float)
        # print(f'np.isclose(preprune, 0).sum(): {np.isclose(preprune, 0).sum()}')

        prune.global_unstructured(
            np.array(prun_list),
            pruning_method=prune.RandomUnstructured,
            amount=prune_p,
        )

        postprune = []
        post_count = 0
        for p in prun_list:
            if p[1] == 'weight':
                if p[0].weight != None:
                    temp = np.ravel(p[0].weight.cpu().detach().numpy()).tolist()
                    # print(f"length appended to preprune: {len(temp)}")
                    postprune.extend(temp)
                    post_count += 1
                else:
                    pass
            elif p[1] == 'bias':
                if p[0].bias != None:
                    temp = np.ravel(p[0].bias.cpu().detach().numpy()).tolist()
                    # print(f"length appended to preprune: {len(temp)}")
                    postprune.extend(temp)
                    post_count += 1
                else:
                    pass
        postprune = np.ravel(postprune).astype(float)

        # print(f'pre_count: {pre_count}')
        # print(f'post_count: {post_count}')
        # print(f'np.isclose(postprune, 0).sum(): {np.isclose(postprune, 0).sum()}')
        

        num_similar_params = np.isclose(preprune, postprune).sum() 
        print(f'num_similar_params: {num_similar_params}')
        print(f'float(len(preprune)): {float(len(preprune))}')

        total_params_pruned = float(len(preprune)) - num_similar_params

        prune_model_size_diff = total_params_pruned/17550466 * 606.85
        print(f'new model size (MB): {606.85 - prune_model_size_diff} vs. old model size(MB): 606.85 MB')
        prune_model_size_percent_saved = prune_model_size_diff/606.85
        print(f'percentage of size saved: {prune_model_size_percent_saved}')


    else:
        num_similar_params = 17550466
        preprune = []
        prune_model_size_diff = 606.85
        prune_model_size_percent_saved = 0
        print("Running base model")
        base_model = False

    # # Estimate Size

    # f = io.StringIO()
    # with redirect_stdout(f):
    #     summary(net, input_size=(3,224,224))
    # out = f.getvalue()

    # total_params = float(out.split("Total params: ")[-1].split("\n")[0].strip().replace(',',''))
    # params_size = float(out.split("Params size (MB): ")[-1].split("\n")[0].strip().replace(',',''))
    # estimated_total_size = float(out.split("Estimated Total Size (MB): ")[-1].split("\n")[0].strip().replace(',',''))
    
    # fname = str(num_params) + '_' + str(prune_p) + '.pt'
    # torch.save(net, fname)

    # fname = str(num_params) + '_' + str(prune_p) + '.pth'
    # torch.save(net.state_dict(), fname)

    # fname = str(num_params) + '_' + str(prune_p) + '.pkl'
    # with open(fname, 'wb') as file:  
    #     pickle.dump(net, file)
    
    
    # file_size = os.path.getsize(fname)
    # print(f'file size: {file_size} bytes')

    # print(total_params)
    # print(params_size)
    # print(estimated_total_size)

    # for fold in test_folds:

    pred_scores = []
    real_scores = []
    rounded_pred_scores = []

    total_model_run_time = 0
        
        # for file_name in fold:
    # count = 0
    for file_name in video_list:
        # print(f'{count}: {file_name}')
        # count += 1
                    
        vid_faces = get_face(file_name)

        # For each frame, we consider the face with the highest confidence score found by BlazeFace (= frame['faces'][0])
        images = [ transf(image=frame['faces'][0])['image'] for frame in vid_faces if len(frame['faces'])]
        faces_t = torch.stack(images)

        # print("Input Size: {}".format(list(net.parameters())[0].shape))

        run_time_start = time.time()
        with torch.no_grad():
            faces_pred = net(faces_t.to(device)).cpu().numpy().flatten()
        run_time_end = time.time()
        run_time_duration = run_time_end - run_time_start
        total_model_run_time += run_time_duration

        pred_scores.append(expit(faces_pred.mean()))
        rounded_pred_scores.append(round(expit(faces_pred.mean())))

        real_scores.append(json_truth_dict[file_name]['label'] != 'REAL')


    """
    Print average scores.
    An average score close to 0 predicts REAL. An average score close to 1 predicts FAKE.
    """

    real_scores = np.array(real_scores).astype(int)   # actual labels
    rounded_pred_scores = np.array(rounded_pred_scores)   # predicted labels
    correct = (real_scores == rounded_pred_scores)

    accuracy = correct.sum() / correct.size

    # print('Names of params pruned: {}'.format(current_run_module_names_string))

    # print('Files tested: {}'.format(video_list))
    # print('Predicted Scores {}'.format(pred_scores))
    # print('Rounded Predicted Scores{}'.format(rounded_pred_scores))
    # print('Real Scores {}'.format(real_scores))
    print('Accuracy: {}'.format(accuracy))
    print('Runtime: {}'.format(total_model_run_time))

    # print('Total Parameters: {}'.format(total_params))
     # print('Parameters Size: {}'.format(params_size))
    # print('Estimated total size: {}'.format(estimated_total_size))

    current_results = [pruning_type, num_params, prune_p, accuracy, total_model_run_time, len(video_list), num_similar_params, 
                        float(len(preprune)), 606.85 - prune_model_size_diff, prune_model_size_percent_saved] + [1] * len(current_run_module_names_list)

    # print("len(current_results): " + str(len(current_results)))
    # print("len(column_names): " + str(len(column_names)))
    # print(column_names)
    # print(f'len(column_names): {len(column_names)}')
    # print(f'len(current_run_module_names_list): {len(current_run_module_names_list)}')
    # print(f'len(current_results): {len(current_results)}')
    print(list(zip(column_names + current_run_module_names_list,current_results)))

    # with mlflow.start_run() as run:
    #     mlflow.log_params({k:v for k,v in zip(column_names + current_run_module_names_list, current_results)})

    result = pd.Series({k:v for k,v in zip(column_names + current_run_module_names_list, current_results)})

    results.append(result)

    print('='*50)

    df = pd.DataFrame(results)
    df.to_csv(f'/content/drive/MyDrive/cs274/resultsRandomUnstructured/{timestamp}.csv')

# df = pd.DataFrame(results, columns=column_names)
# df.to_csv(f'/content/drive/MyDrive/cs274/results/{timestamp}.csv')

    # with mlflow.start_run(run_name="MLflow on Colab"):
    #     mlflow.log_metric("confidence_real", confidence_score_real)
    #     mlflow.log_param("confidence_fake", confidence_score_fake)
    #     mlflow.log_param("run_time", total_model_run_time)
    #     mlflow.log_params(param_dict)
# Out:
# Running base model
# Accuracy: 0.95
# Runtime: 2.0850253105163574
# [('pruning_type', 'global_L1unstructured'), ('num_params', 0), ('percentage_pruned', 0), ('accuracy', 0.95), ('runtime', 2.0850253105163574), ('num_videos', 20), ('num_similar_params', 17550466), ('total_possible_selected_paramters', 0.0), ('new_model_size_mb', 0.0), ('percentage_of_size_saved', 0)]
# ==================================================
# # of modules to be pruned: 420
# % of each module pruned: 0.8
# num_similar_params: 3510104
# float(len(preprune)): 17550466.0
# new model size (MB): 121.37037343623814 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.7999993846317243
# Accuracy: 0.2
# Runtime: 2.109388589859009
# [('pruning_type', 'global_L1unstructured'), ('num_params', 420), ('percentage_pruned', 0.8), ('accuracy', 0.2), ('runtime', 2.109388589859009), ('num_videos', 20), ('num_similar_params', 3510104), ('total_possible_selected_paramters', 17550466.0), ('new_model_size_mb', 121.37037343623814), ('percentage_of_size_saved', 0.7999993846317243), ('efficientnet._conv_stem_weight', 1), ('efficientnet._bn0_bias', 1), ('efficientnet._bn0_weight', 1), ('efficientnet._blocks.0._depthwise_conv_weight', 1), ('efficientnet._blocks.0._bn1_weight', 1), ('efficientnet._blocks.0._bn1_bias', 1), ('efficientnet._blocks.0._se_reduce_weight', 1), ('efficientnet._blocks.0._se_reduce_bias', 1), ('efficientnet._blocks.0._se_expand_bias', 1), ('efficientnet._blocks.0._se_expand_weight', 1), ('efficientnet._blocks.0._project_conv_weight', 1), ('efficientnet._blocks.0._bn2_bias', 1), ('efficientnet._blocks.0._bn2_weight', 1), ('efficientnet._blocks.1._depthwise_conv_weight', 1), ('efficientnet._blocks.1._bn1_weight', 1), ('efficientnet._blocks.1._bn1_bias', 1), ('efficientnet._blocks.1._se_reduce_weight', 1), ('efficientnet._blocks.1._se_reduce_bias', 1), ('efficientnet._blocks.1._se_expand_weight', 1), ('efficientnet._blocks.1._se_expand_bias', 1), ('efficientnet._blocks.1._project_conv_weight', 1), ('efficientnet._blocks.1._bn2_weight', 1), ('efficientnet._blocks.1._bn2_bias', 1), ('efficientnet._blocks.2._expand_conv_weight', 1), ('efficientnet._blocks.2._bn0_bias', 1), ('efficientnet._blocks.2._bn0_weight', 1), ('efficientnet._blocks.2._depthwise_conv_weight', 1), ('efficientnet._blocks.2._bn1_weight', 1), ('efficientnet._blocks.2._bn1_bias', 1), ('efficientnet._blocks.2._se_reduce_bias', 1), ('efficientnet._blocks.2._se_reduce_weight', 1), ('efficientnet._blocks.2._se_expand_weight', 1), ('efficientnet._blocks.2._se_expand_bias', 1), ('efficientnet._blocks.2._project_conv_weight', 1), ('efficientnet._blocks.2._bn2_weight', 1), ('efficientnet._blocks.2._bn2_bias', 1), ('efficientnet._blocks.3._expand_conv_weight', 1), ('efficientnet._blocks.3._bn0_bias', 1), ('efficientnet._blocks.3._bn0_weight', 1), ('efficientnet._blocks.3._depthwise_conv_weight', 1), ('efficientnet._blocks.3._bn1_weight', 1), ('efficientnet._blocks.3._bn1_bias', 1), ('efficientnet._blocks.3._se_reduce_weight', 1), ('efficientnet._blocks.3._se_reduce_bias', 1), ('efficientnet._blocks.3._se_expand_weight', 1), ('efficientnet._blocks.3._se_expand_bias', 1), ('efficientnet._blocks.3._project_conv_weight', 1), ('efficientnet._blocks.3._bn2_bias', 1), ('efficientnet._blocks.3._bn2_weight', 1), ('efficientnet._blocks.4._expand_conv_weight', 1), ('efficientnet._blocks.4._bn0_bias', 1), ('efficientnet._blocks.4._bn0_weight', 1), ('efficientnet._blocks.4._depthwise_conv_weight', 1), ('efficientnet._blocks.4._bn1_bias', 1), ('efficientnet._blocks.4._bn1_weight', 1), ('efficientnet._blocks.4._se_reduce_weight', 1), ('efficientnet._blocks.4._se_reduce_bias', 1), ('efficientnet._blocks.4._se_expand_bias', 1), ('efficientnet._blocks.4._se_expand_weight', 1), ('efficientnet._blocks.4._project_conv_weight', 1), ('efficientnet._blocks.4._bn2_bias', 1), ('efficientnet._blocks.4._bn2_weight', 1), ('efficientnet._blocks.5._expand_conv_weight', 1), ('efficientnet._blocks.5._bn0_weight', 1), ('efficientnet._blocks.5._bn0_bias', 1), ('efficientnet._blocks.5._depthwise_conv_weight', 1), ('efficientnet._blocks.5._bn1_bias', 1), ('efficientnet._blocks.5._bn1_weight', 1), ('efficientnet._blocks.5._se_reduce_weight', 1), ('efficientnet._blocks.5._se_reduce_bias', 1), ('efficientnet._blocks.5._se_expand_weight', 1), ('efficientnet._blocks.5._se_expand_bias', 1), ('efficientnet._blocks.5._project_conv_weight', 1), ('efficientnet._blocks.5._bn2_bias', 1), ('efficientnet._blocks.5._bn2_weight', 1), ('efficientnet._blocks.6._expand_conv_weight', 1), ('efficientnet._blocks.6._bn0_bias', 1), ('efficientnet._blocks.6._bn0_weight', 1), ('efficientnet._blocks.6._depthwise_conv_weight', 1), ('efficientnet._blocks.6._bn1_w ...
# ==================================================
# # of modules to be pruned: 420
# % of each module pruned: 0.7
# num_similar_params: 5265148
# float(len(preprune)): 17550466.0
# new model size (MB): 182.0552835349215 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.6999995327759388
# Accuracy: 0.8
# Runtime: 2.108715772628784
# [('pruning_type', 'global_L1unstructured'), ('num_params', 420), ('percentage_pruned', 0.7), ('accuracy', 0.8), ('runtime', 2.108715772628784), ('num_videos', 20), ('num_similar_params', 5265148), ('total_possible_selected_paramters', 17550466.0), ('new_model_size_mb', 182.0552835349215), ('percentage_of_size_saved', 0.6999995327759388), ('efficientnet._conv_stem_weight', 1), ('efficientnet._bn0_bias', 1), ('efficientnet._bn0_weight', 1), ('efficientnet._blocks.0._depthwise_conv_weight', 1), ('efficientnet._blocks.0._bn1_weight', 1), ('efficientnet._blocks.0._bn1_bias', 1), ('efficientnet._blocks.0._se_reduce_weight', 1), ('efficientnet._blocks.0._se_reduce_bias', 1), ('efficientnet._blocks.0._se_expand_bias', 1), ('efficientnet._blocks.0._se_expand_weight', 1), ('efficientnet._blocks.0._project_conv_weight', 1), ('efficientnet._blocks.0._bn2_weight', 1), ('efficientnet._blocks.0._bn2_bias', 1), ('efficientnet._blocks.1._depthwise_conv_weight', 1), ('efficientnet._blocks.1._bn1_weight', 1), ('efficientnet._blocks.1._bn1_bias', 1), ('efficientnet._blocks.1._se_reduce_bias', 1), ('efficientnet._blocks.1._se_reduce_weight', 1), ('efficientnet._blocks.1._se_expand_bias', 1), ('efficientnet._blocks.1._se_expand_weight', 1), ('efficientnet._blocks.1._project_conv_weight', 1), ('efficientnet._blocks.1._bn2_bias', 1), ('efficientnet._blocks.1._bn2_weight', 1), ('efficientnet._blocks.2._expand_conv_weight', 1), ('efficientnet._blocks.2._bn0_bias', 1), ('efficientnet._blocks.2._bn0_weight', 1), ('efficientnet._blocks.2._depthwise_conv_weight', 1), ('efficientnet._blocks.2._bn1_weight', 1), ('efficientnet._blocks.2._bn1_bias', 1), ('efficientnet._blocks.2._se_reduce_weight', 1), ('efficientnet._blocks.2._se_reduce_bias', 1), ('efficientnet._blocks.2._se_expand_weight', 1), ('efficientnet._blocks.2._se_expand_bias', 1), ('efficientnet._blocks.2._project_conv_weight', 1), ('efficientnet._blocks.2._bn2_weight', 1), ('efficientnet._blocks.2._bn2_bias', 1), ('efficientnet._blocks.3._expand_conv_weight', 1), ('efficientnet._blocks.3._bn0_weight', 1), ('efficientnet._blocks.3._bn0_bias', 1), ('efficientnet._blocks.3._depthwise_conv_weight', 1), ('efficientnet._blocks.3._bn1_bias', 1), ('efficientnet._blocks.3._bn1_weight', 1), ('efficientnet._blocks.3._se_reduce_weight', 1), ('efficientnet._blocks.3._se_reduce_bias', 1), ('efficientnet._blocks.3._se_expand_bias', 1), ('efficientnet._blocks.3._se_expand_weight', 1), ('efficientnet._blocks.3._project_conv_weight', 1), ('efficientnet._blocks.3._bn2_bias', 1), ('efficientnet._blocks.3._bn2_weight', 1), ('efficientnet._blocks.4._expand_conv_weight', 1), ('efficientnet._blocks.4._bn0_bias', 1), ('efficientnet._blocks.4._bn0_weight', 1), ('efficientnet._blocks.4._depthwise_conv_weight', 1), ('efficientnet._blocks.4._bn1_bias', 1), ('efficientnet._blocks.4._bn1_weight', 1), ('efficientnet._blocks.4._se_reduce_weight', 1), ('efficientnet._blocks.4._se_reduce_bias', 1), ('efficientnet._blocks.4._se_expand_bias', 1), ('efficientnet._blocks.4._se_expand_weight', 1), ('efficientnet._blocks.4._project_conv_weight', 1), ('efficientnet._blocks.4._bn2_bias', 1), ('efficientnet._blocks.4._bn2_weight', 1), ('efficientnet._blocks.5._expand_conv_weight', 1), ('efficientnet._blocks.5._bn0_bias', 1), ('efficientnet._blocks.5._bn0_weight', 1), ('efficientnet._blocks.5._depthwise_conv_weight', 1), ('efficientnet._blocks.5._bn1_bias', 1), ('efficientnet._blocks.5._bn1_weight', 1), ('efficientnet._blocks.5._se_reduce_weight', 1), ('efficientnet._blocks.5._se_reduce_bias', 1), ('efficientnet._blocks.5._se_expand_bias', 1), ('efficientnet._blocks.5._se_expand_weight', 1), ('efficientnet._blocks.5._project_conv_weight', 1), ('efficientnet._blocks.5._bn2_bias', 1), ('efficientnet._blocks.5._bn2_weight', 1), ('efficientnet._blocks.6._expand_conv_weight', 1), ('efficientnet._blocks.6._bn0_weight', 1), ('efficientnet._blocks.6._bn0_bias', 1), ('efficientnet._blocks.6._depthwise_conv_weight', 1), ('efficientnet._blocks.6._bn1_we ...
# ==================================================
# # of modules to be pruned: 420
# % of each module pruned: 0.6
# num_similar_params: 7020192
# float(len(preprune)): 17550466.0
# new model size (MB): 242.74019363360497 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.5999996809201533
# Accuracy: 0.2
# Runtime: 2.107762336730957
# [('pruning_type', 'global_L1unstructured'), ('num_params', 420), ('percentage_pruned', 0.6), ('accuracy', 0.2), ('runtime', 2.107762336730957), ('num_videos', 20), ('num_similar_params', 7020192), ('total_possible_selected_paramters', 17550466.0), ('new_model_size_mb', 242.74019363360497), ('percentage_of_size_saved', 0.5999996809201533), ('efficientnet._conv_stem_weight', 1), ('efficientnet._bn0_weight', 1), ('efficientnet._bn0_bias', 1), ('efficientnet._blocks.0._depthwise_conv_weight', 1), ('efficientnet._blocks.0._bn1_bias', 1), ('efficientnet._blocks.0._bn1_weight', 1), ('efficientnet._blocks.0._se_reduce_weight', 1), ('efficientnet._blocks.0._se_reduce_bias', 1), ('efficientnet._blocks.0._se_expand_weight', 1), ('efficientnet._blocks.0._se_expand_bias', 1), ('efficientnet._blocks.0._project_conv_weight', 1), ('efficientnet._blocks.0._bn2_bias', 1), ('efficientnet._blocks.0._bn2_weight', 1), ('efficientnet._blocks.1._depthwise_conv_weight', 1), ('efficientnet._blocks.1._bn1_bias', 1), ('efficientnet._blocks.1._bn1_weight', 1), ('efficientnet._blocks.1._se_reduce_bias', 1), ('efficientnet._blocks.1._se_reduce_weight', 1), ('efficientnet._blocks.1._se_expand_bias', 1), ('efficientnet._blocks.1._se_expand_weight', 1), ('efficientnet._blocks.1._project_conv_weight', 1), ('efficientnet._blocks.1._bn2_bias', 1), ('efficientnet._blocks.1._bn2_weight', 1), ('efficientnet._blocks.2._expand_conv_weight', 1), ('efficientnet._blocks.2._bn0_bias', 1), ('efficientnet._blocks.2._bn0_weight', 1), ('efficientnet._blocks.2._depthwise_conv_weight', 1), ('efficientnet._blocks.2._bn1_bias', 1), ('efficientnet._blocks.2._bn1_weight', 1), ('efficientnet._blocks.2._se_reduce_weight', 1), ('efficientnet._blocks.2._se_reduce_bias', 1), ('efficientnet._blocks.2._se_expand_bias', 1), ('efficientnet._blocks.2._se_expand_weight', 1), ('efficientnet._blocks.2._project_conv_weight', 1), ('efficientnet._blocks.2._bn2_weight', 1), ('efficientnet._blocks.2._bn2_bias', 1), ('efficientnet._blocks.3._expand_conv_weight', 1), ('efficientnet._blocks.3._bn0_weight', 1), ('efficientnet._blocks.3._bn0_bias', 1), ('efficientnet._blocks.3._depthwise_conv_weight', 1), ('efficientnet._blocks.3._bn1_bias', 1), ('efficientnet._blocks.3._bn1_weight', 1), ('efficientnet._blocks.3._se_reduce_weight', 1), ('efficientnet._blocks.3._se_reduce_bias', 1), ('efficientnet._blocks.3._se_expand_bias', 1), ('efficientnet._blocks.3._se_expand_weight', 1), ('efficientnet._blocks.3._project_conv_weight', 1), ('efficientnet._blocks.3._bn2_bias', 1), ('efficientnet._blocks.3._bn2_weight', 1), ('efficientnet._blocks.4._expand_conv_weight', 1), ('efficientnet._blocks.4._bn0_bias', 1), ('efficientnet._blocks.4._bn0_weight', 1), ('efficientnet._blocks.4._depthwise_conv_weight', 1), ('efficientnet._blocks.4._bn1_weight', 1), ('efficientnet._blocks.4._bn1_bias', 1), ('efficientnet._blocks.4._se_reduce_weight', 1), ('efficientnet._blocks.4._se_reduce_bias', 1), ('efficientnet._blocks.4._se_expand_weight', 1), ('efficientnet._blocks.4._se_expand_bias', 1), ('efficientnet._blocks.4._project_conv_weight', 1), ('efficientnet._blocks.4._bn2_weight', 1), ('efficientnet._blocks.4._bn2_bias', 1), ('efficientnet._blocks.5._expand_conv_weight', 1), ('efficientnet._blocks.5._bn0_bias', 1), ('efficientnet._blocks.5._bn0_weight', 1), ('efficientnet._blocks.5._depthwise_conv_weight', 1), ('efficientnet._blocks.5._bn1_bias', 1), ('efficientnet._blocks.5._bn1_weight', 1), ('efficientnet._blocks.5._se_reduce_weight', 1), ('efficientnet._blocks.5._se_reduce_bias', 1), ('efficientnet._blocks.5._se_expand_bias', 1), ('efficientnet._blocks.5._se_expand_weight', 1), ('efficientnet._blocks.5._project_conv_weight', 1), ('efficientnet._blocks.5._bn2_bias', 1), ('efficientnet._blocks.5._bn2_weight', 1), ('efficientnet._blocks.6._expand_conv_weight', 1), ('efficientnet._blocks.6._bn0_bias', 1), ('efficientnet._blocks.6._bn0_weight', 1), ('efficientnet._blocks.6._depthwise_conv_weight', 1), ('efficientnet._blocks.6._bn1_w ...
# ==================================================
# # of modules to be pruned: 420
# % of each module pruned: 0.5
# num_similar_params: 8775237
# float(len(preprune)): 17550466.0
# new model size (MB): 303.42513830971785 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.4999997720858238
# Accuracy: 0.2
# Runtime: 2.107933282852173
# [('pruning_type', 'global_L1unstructured'), ('num_params', 420), ('percentage_pruned', 0.5), ('accuracy', 0.2), ('runtime', 2.107933282852173), ('num_videos', 20), ('num_similar_params', 8775237), ('total_possible_selected_paramters', 17550466.0), ('new_model_size_mb', 303.42513830971785), ('percentage_of_size_saved', 0.4999997720858238), ('efficientnet._conv_stem_weight', 1), ('efficientnet._bn0_bias', 1), ('efficientnet._bn0_weight', 1), ('efficientnet._blocks.0._depthwise_conv_weight', 1), ('efficientnet._blocks.0._bn1_weight', 1), ('efficientnet._blocks.0._bn1_bias', 1), ('efficientnet._blocks.0._se_reduce_bias', 1), ('efficientnet._blocks.0._se_reduce_weight', 1), ('efficientnet._blocks.0._se_expand_bias', 1), ('efficientnet._blocks.0._se_expand_weight', 1), ('efficientnet._blocks.0._project_conv_weight', 1), ('efficientnet._blocks.0._bn2_bias', 1), ('efficientnet._blocks.0._bn2_weight', 1), ('efficientnet._blocks.1._depthwise_conv_weight', 1), ('efficientnet._blocks.1._bn1_bias', 1), ('efficientnet._blocks.1._bn1_weight', 1), ('efficientnet._blocks.1._se_reduce_weight', 1), ('efficientnet._blocks.1._se_reduce_bias', 1), ('efficientnet._blocks.1._se_expand_bias', 1), ('efficientnet._blocks.1._se_expand_weight', 1), ('efficientnet._blocks.1._project_conv_weight', 1), ('efficientnet._blocks.1._bn2_bias', 1), ('efficientnet._blocks.1._bn2_weight', 1), ('efficientnet._blocks.2._expand_conv_weight', 1), ('efficientnet._blocks.2._bn0_bias', 1), ('efficientnet._blocks.2._bn0_weight', 1), ('efficientnet._blocks.2._depthwise_conv_weight', 1), ('efficientnet._blocks.2._bn1_weight', 1), ('efficientnet._blocks.2._bn1_bias', 1), ('efficientnet._blocks.2._se_reduce_bias', 1), ('efficientnet._blocks.2._se_reduce_weight', 1), ('efficientnet._blocks.2._se_expand_bias', 1), ('efficientnet._blocks.2._se_expand_weight', 1), ('efficientnet._blocks.2._project_conv_weight', 1), ('efficientnet._blocks.2._bn2_weight', 1), ('efficientnet._blocks.2._bn2_bias', 1), ('efficientnet._blocks.3._expand_conv_weight', 1), ('efficientnet._blocks.3._bn0_bias', 1), ('efficientnet._blocks.3._bn0_weight', 1), ('efficientnet._blocks.3._depthwise_conv_weight', 1), ('efficientnet._blocks.3._bn1_weight', 1), ('efficientnet._blocks.3._bn1_bias', 1), ('efficientnet._blocks.3._se_reduce_weight', 1), ('efficientnet._blocks.3._se_reduce_bias', 1), ('efficientnet._blocks.3._se_expand_bias', 1), ('efficientnet._blocks.3._se_expand_weight', 1), ('efficientnet._blocks.3._project_conv_weight', 1), ('efficientnet._blocks.3._bn2_weight', 1), ('efficientnet._blocks.3._bn2_bias', 1), ('efficientnet._blocks.4._expand_conv_weight', 1), ('efficientnet._blocks.4._bn0_bias', 1), ('efficientnet._blocks.4._bn0_weight', 1), ('efficientnet._blocks.4._depthwise_conv_weight', 1), ('efficientnet._blocks.4._bn1_weight', 1), ('efficientnet._blocks.4._bn1_bias', 1), ('efficientnet._blocks.4._se_reduce_bias', 1), ('efficientnet._blocks.4._se_reduce_weight', 1), ('efficientnet._blocks.4._se_expand_weight', 1), ('efficientnet._blocks.4._se_expand_bias', 1), ('efficientnet._blocks.4._project_conv_weight', 1), ('efficientnet._blocks.4._bn2_bias', 1), ('efficientnet._blocks.4._bn2_weight', 1), ('efficientnet._blocks.5._expand_conv_weight', 1), ('efficientnet._blocks.5._bn0_bias', 1), ('efficientnet._blocks.5._bn0_weight', 1), ('efficientnet._blocks.5._depthwise_conv_weight', 1), ('efficientnet._blocks.5._bn1_weight', 1), ('efficientnet._blocks.5._bn1_bias', 1), ('efficientnet._blocks.5._se_reduce_bias', 1), ('efficientnet._blocks.5._se_reduce_weight', 1), ('efficientnet._blocks.5._se_expand_weight', 1), ('efficientnet._blocks.5._se_expand_bias', 1), ('efficientnet._blocks.5._project_conv_weight', 1), ('efficientnet._blocks.5._bn2_weight', 1), ('efficientnet._blocks.5._bn2_bias', 1), ('efficientnet._blocks.6._expand_conv_weight', 1), ('efficientnet._blocks.6._bn0_weight', 1), ('efficientnet._blocks.6._bn0_bias', 1), ('efficientnet._blocks.6._depthwise_conv_weight', 1), ('efficientnet._blocks.6._bn1_w ...
# ==================================================
# # of modules to be pruned: 420
# % of each module pruned: 0.4
# num_similar_params: 10530287
# float(len(preprune)): 17550466.0
# new model size (MB): 364.110255872978 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.3999995783587741
# Accuracy: 0.8
# Runtime: 2.105293035507202
# [('pruning_type', 'global_L1unstructured'), ('num_params', 420), ('percentage_pruned', 0.4), ('accuracy', 0.8), ('runtime', 2.105293035507202), ('num_videos', 20), ('num_similar_params', 10530287), ('total_possible_selected_paramters', 17550466.0), ('new_model_size_mb', 364.110255872978), ('percentage_of_size_saved', 0.3999995783587741), ('efficientnet._conv_stem_weight', 1), ('efficientnet._bn0_weight', 1), ('efficientnet._bn0_bias', 1), ('efficientnet._blocks.0._depthwise_conv_weight', 1), ('efficientnet._blocks.0._bn1_weight', 1), ('efficientnet._blocks.0._bn1_bias', 1), ('efficientnet._blocks.0._se_reduce_bias', 1), ('efficientnet._blocks.0._se_reduce_weight', 1), ('efficientnet._blocks.0._se_expand_bias', 1), ('efficientnet._blocks.0._se_expand_weight', 1), ('efficientnet._blocks.0._project_conv_weight', 1), ('efficientnet._blocks.0._bn2_bias', 1), ('efficientnet._blocks.0._bn2_weight', 1), ('efficientnet._blocks.1._depthwise_conv_weight', 1), ('efficientnet._blocks.1._bn1_bias', 1), ('efficientnet._blocks.1._bn1_weight', 1), ('efficientnet._blocks.1._se_reduce_weight', 1), ('efficientnet._blocks.1._se_reduce_bias', 1), ('efficientnet._blocks.1._se_expand_weight', 1), ('efficientnet._blocks.1._se_expand_bias', 1), ('efficientnet._blocks.1._project_conv_weight', 1), ('efficientnet._blocks.1._bn2_bias', 1), ('efficientnet._blocks.1._bn2_weight', 1), ('efficientnet._blocks.2._expand_conv_weight', 1), ('efficientnet._blocks.2._bn0_bias', 1), ('efficientnet._blocks.2._bn0_weight', 1), ('efficientnet._blocks.2._depthwise_conv_weight', 1), ('efficientnet._blocks.2._bn1_weight', 1), ('efficientnet._blocks.2._bn1_bias', 1), ('efficientnet._blocks.2._se_reduce_weight', 1), ('efficientnet._blocks.2._se_reduce_bias', 1), ('efficientnet._blocks.2._se_expand_bias', 1), ('efficientnet._blocks.2._se_expand_weight', 1), ('efficientnet._blocks.2._project_conv_weight', 1), ('efficientnet._blocks.2._bn2_weight', 1), ('efficientnet._blocks.2._bn2_bias', 1), ('efficientnet._blocks.3._expand_conv_weight', 1), ('efficientnet._blocks.3._bn0_weight', 1), ('efficientnet._blocks.3._bn0_bias', 1), ('efficientnet._blocks.3._depthwise_conv_weight', 1), ('efficientnet._blocks.3._bn1_weight', 1), ('efficientnet._blocks.3._bn1_bias', 1), ('efficientnet._blocks.3._se_reduce_bias', 1), ('efficientnet._blocks.3._se_reduce_weight', 1), ('efficientnet._blocks.3._se_expand_bias', 1), ('efficientnet._blocks.3._se_expand_weight', 1), ('efficientnet._blocks.3._project_conv_weight', 1), ('efficientnet._blocks.3._bn2_bias', 1), ('efficientnet._blocks.3._bn2_weight', 1), ('efficientnet._blocks.4._expand_conv_weight', 1), ('efficientnet._blocks.4._bn0_bias', 1), ('efficientnet._blocks.4._bn0_weight', 1), ('efficientnet._blocks.4._depthwise_conv_weight', 1), ('efficientnet._blocks.4._bn1_weight', 1), ('efficientnet._blocks.4._bn1_bias', 1), ('efficientnet._blocks.4._se_reduce_bias', 1), ('efficientnet._blocks.4._se_reduce_weight', 1), ('efficientnet._blocks.4._se_expand_weight', 1), ('efficientnet._blocks.4._se_expand_bias', 1), ('efficientnet._blocks.4._project_conv_weight', 1), ('efficientnet._blocks.4._bn2_bias', 1), ('efficientnet._blocks.4._bn2_weight', 1), ('efficientnet._blocks.5._expand_conv_weight', 1), ('efficientnet._blocks.5._bn0_bias', 1), ('efficientnet._blocks.5._bn0_weight', 1), ('efficientnet._blocks.5._depthwise_conv_weight', 1), ('efficientnet._blocks.5._bn1_weight', 1), ('efficientnet._blocks.5._bn1_bias', 1), ('efficientnet._blocks.5._se_reduce_bias', 1), ('efficientnet._blocks.5._se_reduce_weight', 1), ('efficientnet._blocks.5._se_expand_weight', 1), ('efficientnet._blocks.5._se_expand_bias', 1), ('efficientnet._blocks.5._project_conv_weight', 1), ('efficientnet._blocks.5._bn2_bias', 1), ('efficientnet._blocks.5._bn2_weight', 1), ('efficientnet._blocks.6._expand_conv_weight', 1), ('efficientnet._blocks.6._bn0_bias', 1), ('efficientnet._blocks.6._bn0_weight', 1), ('efficientnet._blocks.6._depthwise_conv_weight', 1), ('efficientnet._blocks.6._bn1_we ...
# ==================================================
# # of modules to be pruned: 420
# % of each module pruned: 0.3
# num_similar_params: 12285330
# float(len(preprune)): 17550466.0
# new model size (MB): 424.79513139423193 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.2999997834815326
# Accuracy: 0.8
# Runtime: 2.1080634593963623
# [('pruning_type', 'global_L1unstructured'), ('num_params', 420), ('percentage_pruned', 0.3), ('accuracy', 0.8), ('runtime', 2.1080634593963623), ('num_videos', 20), ('num_similar_params', 12285330), ('total_possible_selected_paramters', 17550466.0), ('new_model_size_mb', 424.79513139423193), ('percentage_of_size_saved', 0.2999997834815326), ('efficientnet._conv_stem_weight', 1), ('efficientnet._bn0_bias', 1), ('efficientnet._bn0_weight', 1), ('efficientnet._blocks.0._depthwise_conv_weight', 1), ('efficientnet._blocks.0._bn1_bias', 1), ('efficientnet._blocks.0._bn1_weight', 1), ('efficientnet._blocks.0._se_reduce_weight', 1), ('efficientnet._blocks.0._se_reduce_bias', 1), ('efficientnet._blocks.0._se_expand_weight', 1), ('efficientnet._blocks.0._se_expand_bias', 1), ('efficientnet._blocks.0._project_conv_weight', 1), ('efficientnet._blocks.0._bn2_weight', 1), ('efficientnet._blocks.0._bn2_bias', 1), ('efficientnet._blocks.1._depthwise_conv_weight', 1), ('efficientnet._blocks.1._bn1_bias', 1), ('efficientnet._blocks.1._bn1_weight', 1), ('efficientnet._blocks.1._se_reduce_bias', 1), ('efficientnet._blocks.1._se_reduce_weight', 1), ('efficientnet._blocks.1._se_expand_weight', 1), ('efficientnet._blocks.1._se_expand_bias', 1), ('efficientnet._blocks.1._project_conv_weight', 1), ('efficientnet._blocks.1._bn2_weight', 1), ('efficientnet._blocks.1._bn2_bias', 1), ('efficientnet._blocks.2._expand_conv_weight', 1), ('efficientnet._blocks.2._bn0_weight', 1), ('efficientnet._blocks.2._bn0_bias', 1), ('efficientnet._blocks.2._depthwise_conv_weight', 1), ('efficientnet._blocks.2._bn1_bias', 1), ('efficientnet._blocks.2._bn1_weight', 1), ('efficientnet._blocks.2._se_reduce_weight', 1), ('efficientnet._blocks.2._se_reduce_bias', 1), ('efficientnet._blocks.2._se_expand_weight', 1), ('efficientnet._blocks.2._se_expand_bias', 1), ('efficientnet._blocks.2._project_conv_weight', 1), ('efficientnet._blocks.2._bn2_bias', 1), ('efficientnet._blocks.2._bn2_weight', 1), ('efficientnet._blocks.3._expand_conv_weight', 1), ('efficientnet._blocks.3._bn0_weight', 1), ('efficientnet._blocks.3._bn0_bias', 1), ('efficientnet._blocks.3._depthwise_conv_weight', 1), ('efficientnet._blocks.3._bn1_weight', 1), ('efficientnet._blocks.3._bn1_bias', 1), ('efficientnet._blocks.3._se_reduce_weight', 1), ('efficientnet._blocks.3._se_reduce_bias', 1), ('efficientnet._blocks.3._se_expand_bias', 1), ('efficientnet._blocks.3._se_expand_weight', 1), ('efficientnet._blocks.3._project_conv_weight', 1), ('efficientnet._blocks.3._bn2_bias', 1), ('efficientnet._blocks.3._bn2_weight', 1), ('efficientnet._blocks.4._expand_conv_weight', 1), ('efficientnet._blocks.4._bn0_bias', 1), ('efficientnet._blocks.4._bn0_weight', 1), ('efficientnet._blocks.4._depthwise_conv_weight', 1), ('efficientnet._blocks.4._bn1_bias', 1), ('efficientnet._blocks.4._bn1_weight', 1), ('efficientnet._blocks.4._se_reduce_bias', 1), ('efficientnet._blocks.4._se_reduce_weight', 1), ('efficientnet._blocks.4._se_expand_bias', 1), ('efficientnet._blocks.4._se_expand_weight', 1), ('efficientnet._blocks.4._project_conv_weight', 1), ('efficientnet._blocks.4._bn2_weight', 1), ('efficientnet._blocks.4._bn2_bias', 1), ('efficientnet._blocks.5._expand_conv_weight', 1), ('efficientnet._blocks.5._bn0_bias', 1), ('efficientnet._blocks.5._bn0_weight', 1), ('efficientnet._blocks.5._depthwise_conv_weight', 1), ('efficientnet._blocks.5._bn1_bias', 1), ('efficientnet._blocks.5._bn1_weight', 1), ('efficientnet._blocks.5._se_reduce_weight', 1), ('efficientnet._blocks.5._se_reduce_bias', 1), ('efficientnet._blocks.5._se_expand_bias', 1), ('efficientnet._blocks.5._se_expand_weight', 1), ('efficientnet._blocks.5._project_conv_weight', 1), ('efficientnet._blocks.5._bn2_weight', 1), ('efficientnet._blocks.5._bn2_bias', 1), ('efficientnet._blocks.6._expand_conv_weight', 1), ('efficientnet._blocks.6._bn0_weight', 1), ('efficientnet._blocks.6._bn0_bias', 1), ('efficientnet._blocks.6._depthwise_conv_weight', 1), ('efficientnet._blocks.6._bn1 ...
# ==================================================
# # of modules to be pruned: 420
# % of each module pruned: 0.2
# num_similar_params: 14040375
# float(len(preprune)): 17550466.0
# new model size (MB): 485.4800760703448 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.1999998746472031
# Accuracy: 0.2
# Runtime: 2.108901262283325
# [('pruning_type', 'global_L1unstructured'), ('num_params', 420), ('percentage_pruned', 0.2), ('accuracy', 0.2), ('runtime', 2.108901262283325), ('num_videos', 20), ('num_similar_params', 14040375), ('total_possible_selected_paramters', 17550466.0), ('new_model_size_mb', 485.4800760703448), ('percentage_of_size_saved', 0.1999998746472031), ('efficientnet._conv_stem_weight', 1), ('efficientnet._bn0_weight', 1), ('efficientnet._bn0_bias', 1), ('efficientnet._blocks.0._depthwise_conv_weight', 1), ('efficientnet._blocks.0._bn1_weight', 1), ('efficientnet._blocks.0._bn1_bias', 1), ('efficientnet._blocks.0._se_reduce_bias', 1), ('efficientnet._blocks.0._se_reduce_weight', 1), ('efficientnet._blocks.0._se_expand_bias', 1), ('efficientnet._blocks.0._se_expand_weight', 1), ('efficientnet._blocks.0._project_conv_weight', 1), ('efficientnet._blocks.0._bn2_bias', 1), ('efficientnet._blocks.0._bn2_weight', 1), ('efficientnet._blocks.1._depthwise_conv_weight', 1), ('efficientnet._blocks.1._bn1_weight', 1), ('efficientnet._blocks.1._bn1_bias', 1), ('efficientnet._blocks.1._se_reduce_bias', 1), ('efficientnet._blocks.1._se_reduce_weight', 1), ('efficientnet._blocks.1._se_expand_bias', 1), ('efficientnet._blocks.1._se_expand_weight', 1), ('efficientnet._blocks.1._project_conv_weight', 1), ('efficientnet._blocks.1._bn2_bias', 1), ('efficientnet._blocks.1._bn2_weight', 1), ('efficientnet._blocks.2._expand_conv_weight', 1), ('efficientnet._blocks.2._bn0_weight', 1), ('efficientnet._blocks.2._bn0_bias', 1), ('efficientnet._blocks.2._depthwise_conv_weight', 1), ('efficientnet._blocks.2._bn1_bias', 1), ('efficientnet._blocks.2._bn1_weight', 1), ('efficientnet._blocks.2._se_reduce_weight', 1), ('efficientnet._blocks.2._se_reduce_bias', 1), ('efficientnet._blocks.2._se_expand_bias', 1), ('efficientnet._blocks.2._se_expand_weight', 1), ('efficientnet._blocks.2._project_conv_weight', 1), ('efficientnet._blocks.2._bn2_bias', 1), ('efficientnet._blocks.2._bn2_weight', 1), ('efficientnet._blocks.3._expand_conv_weight', 1), ('efficientnet._blocks.3._bn0_bias', 1), ('efficientnet._blocks.3._bn0_weight', 1), ('efficientnet._blocks.3._depthwise_conv_weight', 1), ('efficientnet._blocks.3._bn1_weight', 1), ('efficientnet._blocks.3._bn1_bias', 1), ('efficientnet._blocks.3._se_reduce_bias', 1), ('efficientnet._blocks.3._se_reduce_weight', 1), ('efficientnet._blocks.3._se_expand_bias', 1), ('efficientnet._blocks.3._se_expand_weight', 1), ('efficientnet._blocks.3._project_conv_weight', 1), ('efficientnet._blocks.3._bn2_bias', 1), ('efficientnet._blocks.3._bn2_weight', 1), ('efficientnet._blocks.4._expand_conv_weight', 1), ('efficientnet._blocks.4._bn0_bias', 1), ('efficientnet._blocks.4._bn0_weight', 1), ('efficientnet._blocks.4._depthwise_conv_weight', 1), ('efficientnet._blocks.4._bn1_bias', 1), ('efficientnet._blocks.4._bn1_weight', 1), ('efficientnet._blocks.4._se_reduce_weight', 1), ('efficientnet._blocks.4._se_reduce_bias', 1), ('efficientnet._blocks.4._se_expand_bias', 1), ('efficientnet._blocks.4._se_expand_weight', 1), ('efficientnet._blocks.4._project_conv_weight', 1), ('efficientnet._blocks.4._bn2_bias', 1), ('efficientnet._blocks.4._bn2_weight', 1), ('efficientnet._blocks.5._expand_conv_weight', 1), ('efficientnet._blocks.5._bn0_bias', 1), ('efficientnet._blocks.5._bn0_weight', 1), ('efficientnet._blocks.5._depthwise_conv_weight', 1), ('efficientnet._blocks.5._bn1_bias', 1), ('efficientnet._blocks.5._bn1_weight', 1), ('efficientnet._blocks.5._se_reduce_bias', 1), ('efficientnet._blocks.5._se_reduce_weight', 1), ('efficientnet._blocks.5._se_expand_bias', 1), ('efficientnet._blocks.5._se_expand_weight', 1), ('efficientnet._blocks.5._project_conv_weight', 1), ('efficientnet._blocks.5._bn2_weight', 1), ('efficientnet._blocks.5._bn2_bias', 1), ('efficientnet._blocks.6._expand_conv_weight', 1), ('efficientnet._blocks.6._bn0_bias', 1), ('efficientnet._blocks.6._bn0_weight', 1), ('efficientnet._blocks.6._depthwise_conv_weight', 1), ('efficientnet._blocks.6._bn1_w ...
# ==================================================
# # of modules to be pruned: 380
# % of each module pruned: 0.8
# num_similar_params: 3245217
# float(len(preprune)): 16226039.0
# new model size (MB): 158.0065430399398 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.7396283380737583
# Accuracy: 0.2
# Runtime: 2.106086492538452
# [('pruning_type', 'global_L1unstructured'), ('num_params', 380), ('percentage_pruned', 0.8), ('accuracy', 0.2), ('runtime', 2.106086492538452), ('num_videos', 20), ('num_similar_params', 3245217), ('total_possible_selected_paramters', 16226039.0), ('new_model_size_mb', 158.0065430399398), ('percentage_of_size_saved', 0.7396283380737583), ('efficientnet._conv_stem_weight', 1), ('efficientnet._bn0_bias', 1), ('efficientnet._bn0_weight', 1), ('efficientnet._blocks.0._depthwise_conv_weight', 1), ('efficientnet._blocks.0._bn1_weight', 1), ('efficientnet._blocks.0._bn1_bias', 1), ('efficientnet._blocks.0._se_reduce_bias', 1), ('efficientnet._blocks.0._se_reduce_weight', 1), ('efficientnet._blocks.0._se_expand_bias', 1), ('efficientnet._blocks.0._project_conv_weight', 1), ('efficientnet._blocks.0._bn2_bias', 1), ('efficientnet._blocks.1._depthwise_conv_weight', 1), ('efficientnet._blocks.1._bn1_weight', 1), ('efficientnet._blocks.1._bn1_bias', 1), ('efficientnet._blocks.1._se_reduce_weight', 1), ('efficientnet._blocks.1._se_expand_bias', 1), ('efficientnet._blocks.1._se_expand_weight', 1), ('efficientnet._blocks.1._project_conv_weight', 1), ('efficientnet._blocks.1._bn2_bias', 1), ('efficientnet._blocks.1._bn2_weight', 1), ('efficientnet._blocks.2._expand_conv_weight', 1), ('efficientnet._blocks.2._bn0_bias', 1), ('efficientnet._blocks.2._depthwise_conv_weight', 1), ('efficientnet._blocks.2._bn1_weight', 1), ('efficientnet._blocks.2._bn1_bias', 1), ('efficientnet._blocks.2._se_reduce_bias', 1), ('efficientnet._blocks.2._se_reduce_weight', 1), ('efficientnet._blocks.2._se_expand_weight', 1), ('efficientnet._blocks.2._se_expand_bias', 1), ('efficientnet._blocks.2._project_conv_weight', 1), ('efficientnet._blocks.2._bn2_weight', 1), ('efficientnet._blocks.2._bn2_bias', 1), ('efficientnet._blocks.3._expand_conv_weight', 1), ('efficientnet._blocks.3._bn0_weight', 1), ('efficientnet._blocks.3._depthwise_conv_weight', 1), ('efficientnet._blocks.3._bn1_weight', 1), ('efficientnet._blocks.3._bn1_bias', 1), ('efficientnet._blocks.3._se_reduce_weight', 1), ('efficientnet._blocks.3._se_reduce_bias', 1), ('efficientnet._blocks.3._se_expand_weight', 1), ('efficientnet._blocks.3._project_conv_weight', 1), ('efficientnet._blocks.3._bn2_weight', 1), ('efficientnet._blocks.3._bn2_bias', 1), ('efficientnet._blocks.4._bn0_bias', 1), ('efficientnet._blocks.4._depthwise_conv_weight', 1), ('efficientnet._blocks.4._bn1_bias', 1), ('efficientnet._blocks.4._bn1_weight', 1), ('efficientnet._blocks.4._se_reduce_bias', 1), ('efficientnet._blocks.4._se_reduce_weight', 1), ('efficientnet._blocks.4._se_expand_bias', 1), ('efficientnet._blocks.4._se_expand_weight', 1), ('efficientnet._blocks.4._project_conv_weight', 1), ('efficientnet._blocks.4._bn2_weight', 1), ('efficientnet._blocks.4._bn2_bias', 1), ('efficientnet._blocks.5._expand_conv_weight', 1), ('efficientnet._blocks.5._bn0_bias', 1), ('efficientnet._blocks.5._bn0_weight', 1), ('efficientnet._blocks.5._depthwise_conv_weight', 1), ('efficientnet._blocks.5._bn1_bias', 1), ('efficientnet._blocks.5._bn1_weight', 1), ('efficientnet._blocks.5._se_reduce_weight', 1), ('efficientnet._blocks.5._se_reduce_bias', 1), ('efficientnet._blocks.5._se_expand_weight', 1), ('efficientnet._blocks.5._se_expand_bias', 1), ('efficientnet._blocks.5._project_conv_weight', 1), ('efficientnet._blocks.5._bn2_weight', 1), ('efficientnet._blocks.5._bn2_bias', 1), ('efficientnet._blocks.6._expand_conv_weight', 1), ('efficientnet._blocks.6._bn0_bias', 1), ('efficientnet._blocks.6._bn0_weight', 1), ('efficientnet._blocks.6._depthwise_conv_weight', 1), ('efficientnet._blocks.6._bn1_bias', 1), ('efficientnet._blocks.6._bn1_weight', 1), ('efficientnet._blocks.6._se_reduce_weight', 1), ('efficientnet._blocks.6._se_reduce_bias', 1), ('efficientnet._blocks.6._se_expand_bias', 1), ('efficientnet._blocks.6._project_conv_weight', 1), ('efficientnet._blocks.6._bn2_bias', 1), ('efficientnet._blocks.6._bn2_weight', 1), ('efficientnet._blocks.7._expand_ ...
# ==================================================
# # of modules to be pruned: 380
# % of each module pruned: 0.7
# num_similar_params: 4713816
# float(len(preprune)): 15712696.0
# new model size (MB): 226.53700272687922 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.6267001685311375
# Accuracy: 0.2
# Runtime: 2.102792739868164
# [('pruning_type', 'global_L1unstructured'), ('num_params', 380), ('percentage_pruned', 0.7), ('accuracy', 0.2), ('runtime', 2.102792739868164), ('num_videos', 20), ('num_similar_params', 4713816), ('total_possible_selected_paramters', 15712696.0), ('new_model_size_mb', 226.53700272687922), ('percentage_of_size_saved', 0.6267001685311375), ('efficientnet._conv_stem_weight', 1), ('efficientnet._bn0_weight', 1), ('efficientnet._bn0_bias', 1), ('efficientnet._blocks.0._depthwise_conv_weight', 1), ('efficientnet._blocks.0._bn1_weight', 1), ('efficientnet._blocks.0._bn1_bias', 1), ('efficientnet._blocks.0._se_reduce_bias', 1), ('efficientnet._blocks.0._se_reduce_weight', 1), ('efficientnet._blocks.0._se_expand_weight', 1), ('efficientnet._blocks.0._se_expand_bias', 1), ('efficientnet._blocks.0._project_conv_weight', 1), ('efficientnet._blocks.0._bn2_weight', 1), ('efficientnet._blocks.1._depthwise_conv_weight', 1), ('efficientnet._blocks.1._bn1_bias', 1), ('efficientnet._blocks.1._bn1_weight', 1), ('efficientnet._blocks.1._se_reduce_bias', 1), ('efficientnet._blocks.1._se_expand_weight', 1), ('efficientnet._blocks.1._project_conv_weight', 1), ('efficientnet._blocks.1._bn2_bias', 1), ('efficientnet._blocks.1._bn2_weight', 1), ('efficientnet._blocks.2._expand_conv_weight', 1), ('efficientnet._blocks.2._bn0_bias', 1), ('efficientnet._blocks.2._bn0_weight', 1), ('efficientnet._blocks.2._depthwise_conv_weight', 1), ('efficientnet._blocks.2._bn1_weight', 1), ('efficientnet._blocks.2._se_reduce_weight', 1), ('efficientnet._blocks.2._se_expand_bias', 1), ('efficientnet._blocks.2._se_expand_weight', 1), ('efficientnet._blocks.2._project_conv_weight', 1), ('efficientnet._blocks.2._bn2_weight', 1), ('efficientnet._blocks.2._bn2_bias', 1), ('efficientnet._blocks.3._expand_conv_weight', 1), ('efficientnet._blocks.3._bn0_bias', 1), ('efficientnet._blocks.3._bn0_weight', 1), ('efficientnet._blocks.3._bn1_weight', 1), ('efficientnet._blocks.3._bn1_bias', 1), ('efficientnet._blocks.3._se_reduce_weight', 1), ('efficientnet._blocks.3._se_reduce_bias', 1), ('efficientnet._blocks.3._se_expand_bias', 1), ('efficientnet._blocks.3._se_expand_weight', 1), ('efficientnet._blocks.3._project_conv_weight', 1), ('efficientnet._blocks.3._bn2_bias', 1), ('efficientnet._blocks.4._expand_conv_weight', 1), ('efficientnet._blocks.4._bn0_weight', 1), ('efficientnet._blocks.4._depthwise_conv_weight', 1), ('efficientnet._blocks.4._bn1_bias', 1), ('efficientnet._blocks.4._bn1_weight', 1), ('efficientnet._blocks.4._se_reduce_bias', 1), ('efficientnet._blocks.4._se_expand_weight', 1), ('efficientnet._blocks.4._se_expand_bias', 1), ('efficientnet._blocks.4._project_conv_weight', 1), ('efficientnet._blocks.4._bn2_bias', 1), ('efficientnet._blocks.4._bn2_weight', 1), ('efficientnet._blocks.5._expand_conv_weight', 1), ('efficientnet._blocks.5._bn0_bias', 1), ('efficientnet._blocks.5._bn0_weight', 1), ('efficientnet._blocks.5._depthwise_conv_weight', 1), ('efficientnet._blocks.5._bn1_bias', 1), ('efficientnet._blocks.5._bn1_weight', 1), ('efficientnet._blocks.5._se_reduce_bias', 1), ('efficientnet._blocks.5._se_expand_bias', 1), ('efficientnet._blocks.5._se_expand_weight', 1), ('efficientnet._blocks.5._project_conv_weight', 1), ('efficientnet._blocks.5._bn2_bias', 1), ('efficientnet._blocks.5._bn2_weight', 1), ('efficientnet._blocks.6._expand_conv_weight', 1), ('efficientnet._blocks.6._bn0_bias', 1), ('efficientnet._blocks.6._bn0_weight', 1), ('efficientnet._blocks.6._bn1_weight', 1), ('efficientnet._blocks.6._se_reduce_weight', 1), ('efficientnet._blocks.6._se_reduce_bias', 1), ('efficientnet._blocks.6._se_expand_weight', 1), ('efficientnet._blocks.6._se_expand_bias', 1), ('efficientnet._blocks.6._project_conv_weight', 1), ('efficientnet._blocks.6._bn2_bias', 1), ('efficientnet._blocks.6._bn2_weight', 1), ('efficientnet._blocks.7._expand_conv_weight', 1), ('efficientnet._blocks.7._bn0_bias', 1), ('efficientnet._blocks.7._bn0_weight', 1), ('efficientnet._blocks.7._depthwise_conv ...
# ==================================================
# # of modules to be pruned: 380
# % of each module pruned: 0.6
# num_similar_params: 6442216
# float(len(preprune)): 16105522.0
# new model size (MB): 272.71771849248904 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.5506011065461168
# Accuracy: 0.8
# Runtime: 2.1050000190734863
# [('pruning_type', 'global_L1unstructured'), ('num_params', 380), ('percentage_pruned', 0.6), ('accuracy', 0.8), ('runtime', 2.1050000190734863), ('num_videos', 20), ('num_similar_params', 6442216), ('total_possible_selected_paramters', 16105522.0), ('new_model_size_mb', 272.71771849248904), ('percentage_of_size_saved', 0.5506011065461168), ('efficientnet._conv_stem_weight', 1), ('efficientnet._bn0_weight', 1), ('efficientnet._bn0_bias', 1), ('efficientnet._blocks.0._depthwise_conv_weight', 1), ('efficientnet._blocks.0._bn1_weight', 1), ('efficientnet._blocks.0._bn1_bias', 1), ('efficientnet._blocks.0._se_reduce_weight', 1), ('efficientnet._blocks.0._se_reduce_bias', 1), ('efficientnet._blocks.0._se_expand_weight', 1), ('efficientnet._blocks.0._project_conv_weight', 1), ('efficientnet._blocks.0._bn2_bias', 1), ('efficientnet._blocks.0._bn2_weight', 1), ('efficientnet._blocks.1._depthwise_conv_weight', 1), ('efficientnet._blocks.1._bn1_bias', 1), ('efficientnet._blocks.1._bn1_weight', 1), ('efficientnet._blocks.1._se_reduce_weight', 1), ('efficientnet._blocks.1._se_reduce_bias', 1), ('efficientnet._blocks.1._se_expand_bias', 1), ('efficientnet._blocks.1._se_expand_weight', 1), ('efficientnet._blocks.1._project_conv_weight', 1), ('efficientnet._blocks.1._bn2_bias', 1), ('efficientnet._blocks.1._bn2_weight', 1), ('efficientnet._blocks.2._expand_conv_weight', 1), ('efficientnet._blocks.2._bn0_weight', 1), ('efficientnet._blocks.2._bn0_bias', 1), ('efficientnet._blocks.2._depthwise_conv_weight', 1), ('efficientnet._blocks.2._bn1_weight', 1), ('efficientnet._blocks.2._se_reduce_weight', 1), ('efficientnet._blocks.2._se_reduce_bias', 1), ('efficientnet._blocks.2._se_expand_weight', 1), ('efficientnet._blocks.2._se_expand_bias', 1), ('efficientnet._blocks.2._project_conv_weight', 1), ('efficientnet._blocks.2._bn2_weight', 1), ('efficientnet._blocks.2._bn2_bias', 1), ('efficientnet._blocks.3._bn0_weight', 1), ('efficientnet._blocks.3._bn1_weight', 1), ('efficientnet._blocks.3._bn1_bias', 1), ('efficientnet._blocks.3._se_reduce_weight', 1), ('efficientnet._blocks.3._se_reduce_bias', 1), ('efficientnet._blocks.3._se_expand_weight', 1), ('efficientnet._blocks.3._se_expand_bias', 1), ('efficientnet._blocks.3._project_conv_weight', 1), ('efficientnet._blocks.3._bn2_bias', 1), ('efficientnet._blocks.4._expand_conv_weight', 1), ('efficientnet._blocks.4._bn0_weight', 1), ('efficientnet._blocks.4._bn0_bias', 1), ('efficientnet._blocks.4._depthwise_conv_weight', 1), ('efficientnet._blocks.4._bn1_bias', 1), ('efficientnet._blocks.4._bn1_weight', 1), ('efficientnet._blocks.4._se_reduce_bias', 1), ('efficientnet._blocks.4._se_expand_bias', 1), ('efficientnet._blocks.4._se_expand_weight', 1), ('efficientnet._blocks.4._project_conv_weight', 1), ('efficientnet._blocks.4._bn2_weight', 1), ('efficientnet._blocks.4._bn2_bias', 1), ('efficientnet._blocks.5._expand_conv_weight', 1), ('efficientnet._blocks.5._bn0_weight', 1), ('efficientnet._blocks.5._depthwise_conv_weight', 1), ('efficientnet._blocks.5._bn1_weight', 1), ('efficientnet._blocks.5._se_reduce_bias', 1), ('efficientnet._blocks.5._se_reduce_weight', 1), ('efficientnet._blocks.5._se_expand_bias', 1), ('efficientnet._blocks.5._project_conv_weight', 1), ('efficientnet._blocks.5._bn2_bias', 1), ('efficientnet._blocks.5._bn2_weight', 1), ('efficientnet._blocks.6._expand_conv_weight', 1), ('efficientnet._blocks.6._bn0_weight', 1), ('efficientnet._blocks.6._bn0_bias', 1), ('efficientnet._blocks.6._depthwise_conv_weight', 1), ('efficientnet._blocks.6._bn1_weight', 1), ('efficientnet._blocks.6._se_reduce_weight', 1), ('efficientnet._blocks.6._se_reduce_bias', 1), ('efficientnet._blocks.6._se_expand_bias', 1), ('efficientnet._blocks.6._bn2_weight', 1), ('efficientnet._blocks.6._bn2_bias', 1), ('efficientnet._blocks.7._expand_conv_weight', 1), ('efficientnet._blocks.7._bn0_bias', 1), ('efficientnet._blocks.7._bn0_weight', 1), ('efficientnet._blocks.7._depthwise_conv_weight', 1), ('efficientnet._blocks.7._bn ...
# ==================================================
# # of modules to be pruned: 380
# % of each module pruned: 0.5
# num_similar_params: 8286476
# float(len(preprune)): 16572942.0
# new model size (MB): 320.3253064619481 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.47215076796251443
# Accuracy: 0.8
# Runtime: 2.105290651321411
# ...
# ==================================================
# # of modules to be pruned: 60
# % of each module pruned: 0.2
# num_similar_params: 1587413
# float(len(preprune)): 1984266.0
# new model size (MB): 593.1278433888879 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.022612106140087677
# Accuracy: 0.35
# Runtime: 2.0711677074432373
# [('pruning_type', 'global_L1unstructured'), ('num_params', 60), ('percentage_pruned', 0.2), ('accuracy', 0.35), ('runtime', 2.0711677074432373), ('num_videos', 20), ('num_similar_params', 1587413), ('total_possible_selected_paramters', 1984266.0), ('new_model_size_mb', 593.1278433888879), ('percentage_of_size_saved', 0.022612106140087677), ('efficientnet._blocks.0._se_expand_weight', 1), ('efficientnet._blocks.1._bn1_weight', 1), ('efficientnet._blocks.1._se_reduce_bias', 1), ('efficientnet._blocks.1._bn2_weight', 1), ('efficientnet._blocks.2._bn1_weight', 1), ('efficientnet._blocks.2._bn2_bias', 1), ('efficientnet._blocks.3._bn0_weight', 1), ('efficientnet._blocks.4._expand_conv_weight', 1), ('efficientnet._blocks.4._bn1_weight', 1), ('efficientnet._blocks.4._se_reduce_weight', 1), ('efficientnet._blocks.4._bn2_weight', 1), ('efficientnet._blocks.5._depthwise_conv_weight', 1), ('efficientnet._blocks.5._bn1_weight', 1), ('efficientnet._blocks.6._se_reduce_bias', 1), ('efficientnet._blocks.7._se_expand_weight', 1), ('efficientnet._blocks.8._bn1_weight', 1), ('efficientnet._blocks.9._depthwise_conv_weight', 1), ('efficientnet._blocks.9._se_expand_bias', 1), ('efficientnet._blocks.9._project_conv_weight', 1), ('efficientnet._blocks.9._bn2_bias', 1), ('efficientnet._blocks.10._expand_conv_weight', 1), ('efficientnet._blocks.11._bn0_bias', 1), ('efficientnet._blocks.11._se_reduce_bias', 1), ('efficientnet._blocks.11._bn2_bias', 1), ('efficientnet._blocks.12._depthwise_conv_weight', 1), ('efficientnet._blocks.12._bn1_bias', 1), ('efficientnet._blocks.12._bn1_weight', 1), ('efficientnet._blocks.12._bn2_weight', 1), ('efficientnet._blocks.13._depthwise_conv_weight', 1), ('efficientnet._blocks.13._se_expand_bias', 1), ('efficientnet._blocks.13._se_expand_weight', 1), ('efficientnet._blocks.14._se_reduce_weight', 1), ('efficientnet._blocks.15._expand_conv_weight', 1), ('efficientnet._blocks.15._se_reduce_bias', 1), ('efficientnet._blocks.16._se_reduce_weight', 1), ('efficientnet._blocks.17._se_reduce_weight', 1), ('efficientnet._blocks.18._bn0_weight', 1), ('efficientnet._blocks.19._depthwise_conv_weight', 1), ('efficientnet._blocks.20._se_expand_weight', 1), ('efficientnet._blocks.20._se_expand_bias', 1), ('efficientnet._blocks.21._se_expand_bias', 1), ('efficientnet._blocks.22._depthwise_conv_weight', 1), ('efficientnet._blocks.22._se_reduce_bias', 1), ('efficientnet._blocks.23._project_conv_weight', 1), ('efficientnet._blocks.24._bn0_bias', 1), ('efficientnet._blocks.24._bn0_weight', 1), ('efficientnet._blocks.24._se_expand_bias', 1), ('efficientnet._blocks.25._depthwise_conv_weight', 1), ('efficientnet._blocks.25._bn1_weight', 1), ('efficientnet._blocks.26._bn1_bias', 1), ('efficientnet._blocks.27._se_expand_weight', 1), ('efficientnet._blocks.28._expand_conv_weight', 1), ('efficientnet._blocks.28._bn0_bias', 1), ('efficientnet._blocks.28._depthwise_conv_weight', 1), ('efficientnet._blocks.28._se_reduce_weight', 1), ('efficientnet._blocks.28._bn2_weight', 1), ('efficientnet._blocks.29._bn0_weight', 1), ('efficientnet._blocks.30._expand_conv_weight', 1), ('efficientnet._blocks.30._se_reduce_bias', 1), ('efficientnet._blocks.30._bn2_weight', 1)]
# ==================================================
# # of modules to be pruned: 20
# % of each module pruned: 0.8
# num_similar_params: 177830
# float(len(preprune)): 889144.0
# new model size (MB): 582.2545903453504 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.040529636079178755
# Accuracy: 0.2
# Runtime: 2.061136484146118
# [('pruning_type', 'global_L1unstructured'), ('num_params', 20), ('percentage_pruned', 0.8), ('accuracy', 0.2), ('runtime', 2.061136484146118), ('num_videos', 20), ('num_similar_params', 177830), ('total_possible_selected_paramters', 889144.0), ('new_model_size_mb', 582.2545903453504), ('percentage_of_size_saved', 0.040529636079178755), ('efficientnet._blocks.5._se_reduce_weight', 1), ('efficientnet._blocks.6._bn2_weight', 1), ('efficientnet._blocks.8._bn1_weight', 1), ('efficientnet._blocks.8._project_conv_weight', 1), ('efficientnet._blocks.11._depthwise_conv_weight', 1), ('efficientnet._blocks.11._bn1_bias', 1), ('efficientnet._blocks.11._se_expand_weight', 1), ('efficientnet._blocks.14._expand_conv_weight', 1), ('efficientnet._blocks.14._depthwise_conv_weight', 1), ('efficientnet._blocks.15._bn1_bias', 1), ('efficientnet._blocks.15._project_conv_weight', 1), ('efficientnet._blocks.20._bn1_weight', 1), ('efficientnet._blocks.22._expand_conv_weight', 1), ('efficientnet._blocks.22._bn1_bias', 1), ('efficientnet._blocks.23._depthwise_conv_weight', 1), ('efficientnet._blocks.25._project_conv_weight', 1), ('efficientnet._blocks.28._bn0_bias', 1), ('efficientnet._blocks.29._depthwise_conv_weight', 1), ('efficientnet._blocks.29._bn2_bias', 1), ('efficientnet._blocks.31._bn1_bias', 1)]
# ==================================================
# # of modules to be pruned: 20
# % of each module pruned: 0.7
# num_similar_params: 251789
# float(len(preprune)): 839296.0
# new model size (MB): 586.535518153763 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.03347529347653789
# Accuracy: 0.2
# Runtime: 2.0617129802703857
# [('pruning_type', 'global_L1unstructured'), ('num_params', 20), ('percentage_pruned', 0.7), ('accuracy', 0.2), ('runtime', 2.0617129802703857), ('num_videos', 20), ('num_similar_params', 251789), ('total_possible_selected_paramters', 839296.0), ('new_model_size_mb', 586.535518153763), ('percentage_of_size_saved', 0.03347529347653789), ('efficientnet._blocks.0._depthwise_conv_weight', 1), ('efficientnet._blocks.4._bn0_bias', 1), ('efficientnet._blocks.6._bn0_weight', 1), ('efficientnet._blocks.7._se_expand_weight', 1), ('efficientnet._blocks.12._expand_conv_weight', 1), ('efficientnet._blocks.12._bn1_weight', 1), ('efficientnet._blocks.13._expand_conv_weight', 1), ('efficientnet._blocks.13._project_conv_weight', 1), ('efficientnet._blocks.17._se_expand_bias', 1), ('efficientnet._blocks.18._bn0_weight', 1), ('efficientnet._blocks.20._bn0_bias', 1), ('efficientnet._blocks.23._bn1_weight', 1), ('efficientnet._blocks.24._depthwise_conv_weight', 1), ('efficientnet._blocks.25._bn2_bias', 1), ('efficientnet._blocks.26._bn1_weight', 1), ('efficientnet._blocks.27._se_expand_weight', 1), ('efficientnet._blocks.28._bn1_bias', 1), ('efficientnet._blocks.28._project_conv_weight', 1), ('efficientnet._bn1_weight', 1), ('classifier_weight', 1)]
# ==================================================
# # of modules to be pruned: 20
# % of each module pruned: 0.6
# num_similar_params: 777069
# float(len(preprune)): 1942672.0
# new model size (MB): 566.5464444961177 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.0664143618750636
# Accuracy: 0.55
# Runtime: 2.062579870223999
# [('pruning_type', 'global_L1unstructured'), ('num_params', 20), ('percentage_pruned', 0.6), ('accuracy', 0.55), ('runtime', 2.062579870223999), ('num_videos', 20), ('num_similar_params', 777069), ('total_possible_selected_paramters', 1942672.0), ('new_model_size_mb', 566.5464444961177), ('percentage_of_size_saved', 0.0664143618750636), ('efficientnet._blocks.1._se_reduce_weight', 1), ('efficientnet._blocks.1._project_conv_weight', 1), ('efficientnet._blocks.2._depthwise_conv_weight', 1), ('efficientnet._blocks.2._bn2_bias', 1), ('efficientnet._blocks.3._bn1_bias', 1), ('efficientnet._blocks.5._bn0_bias', 1), ('efficientnet._blocks.6._bn1_bias', 1), ('efficientnet._blocks.10._expand_conv_weight', 1), ('efficientnet._blocks.11._depthwise_conv_weight', 1), ('efficientnet._blocks.12._se_expand_weight', 1), ('efficientnet._blocks.13._depthwise_conv_weight', 1), ('efficientnet._blocks.15._project_conv_weight', 1), ('efficientnet._blocks.15._bn2_weight', 1), ('efficientnet._blocks.17._bn1_bias', 1), ('efficientnet._blocks.18._expand_conv_weight', 1), ('efficientnet._blocks.25._bn1_weight', 1), ('efficientnet._blocks.27._expand_conv_weight', 1), ('efficientnet._blocks.29._se_expand_weight', 1), ('efficientnet._blocks.31._se_expand_weight', 1), ('efficientnet._conv_head_weight', 1)]
# ==================================================
# # of modules to be pruned: 20
# % of each module pruned: 0.5
# num_similar_params: 838816
# float(len(preprune)): 1677632.0
# new model size (MB): 577.8458989351052 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.04779451440206773
# Accuracy: 0.8
# Runtime: 2.064990282058716
# [('pruning_type', 'global_L1unstructured'), ('num_params', 20), ('percentage_pruned', 0.5), ('accuracy', 0.8), ('runtime', 2.064990282058716), ('num_videos', 20), ('num_similar_params', 838816), ('total_possible_selected_paramters', 1677632.0), ('new_model_size_mb', 577.8458989351052), ('percentage_of_size_saved', 0.04779451440206773), ('efficientnet._blocks.1._se_reduce_weight', 1), ('efficientnet._blocks.6._depthwise_conv_weight', 1), ('efficientnet._blocks.8._depthwise_conv_weight', 1), ('efficientnet._blocks.8._project_conv_weight', 1), ('efficientnet._blocks.9._bn1_weight', 1), ('efficientnet._blocks.9._se_reduce_weight', 1), ('efficientnet._blocks.12._se_expand_bias', 1), ('efficientnet._blocks.14._bn1_bias', 1), ('efficientnet._blocks.14._se_reduce_weight', 1), ('efficientnet._blocks.15._bn1_bias', 1), ('efficientnet._blocks.15._se_reduce_weight', 1), ('efficientnet._blocks.21._project_conv_weight', 1), ('efficientnet._blocks.22._bn1_bias', 1), ('efficientnet._blocks.23._bn0_weight', 1), ('efficientnet._blocks.23._project_conv_weight', 1), ('efficientnet._blocks.24._project_conv_weight', 1), ('efficientnet._blocks.25._project_conv_weight', 1), ('efficientnet._blocks.26._bn2_bias', 1), ('efficientnet._blocks.28._bn0_bias', 1), ('efficientnet._blocks.29._se_reduce_weight', 1)]
# ==================================================
# # of modules to be pruned: 20
# % of each module pruned: 0.4
# num_similar_params: 52102
# float(len(preprune)): 86836.0
# new model size (MB): 605.6489875653444 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.001979092748876298
# Accuracy: 0.8
# Runtime: 2.0640804767608643
# [('pruning_type', 'global_L1unstructured'), ('num_params', 20), ('percentage_pruned', 0.4), ('accuracy', 0.8), ('runtime', 2.0640804767608643), ('num_videos', 20), ('num_similar_params', 52102), ('total_possible_selected_paramters', 86836.0), ('new_model_size_mb', 605.6489875653444), ('percentage_of_size_saved', 0.001979092748876298), ('efficientnet._blocks.0._bn1_bias', 1), ('efficientnet._blocks.1._bn2_bias', 1), ('efficientnet._blocks.2._expand_conv_weight', 1), ('efficientnet._blocks.3._se_expand_weight', 1), ('efficientnet._blocks.4._expand_conv_weight', 1), ('efficientnet._blocks.4._depthwise_conv_weight', 1), ('efficientnet._blocks.4._se_reduce_weight', 1), ('efficientnet._blocks.4._project_conv_weight', 1), ('efficientnet._blocks.6._se_expand_weight', 1), ('efficientnet._blocks.7._bn1_weight', 1), ('efficientnet._blocks.7._project_conv_weight', 1), ('efficientnet._blocks.8._expand_conv_weight', 1), ('efficientnet._blocks.11._bn1_weight', 1), ('efficientnet._blocks.15._se_reduce_weight', 1), ('efficientnet._blocks.16._se_reduce_bias', 1), ('efficientnet._blocks.17._bn1_weight', 1), ('efficientnet._blocks.18._se_expand_bias', 1), ('efficientnet._blocks.19._bn1_weight', 1), ('efficientnet._blocks.25._se_expand_bias', 1), ('efficientnet._blocks.31._bn0_weight', 1)]
# ==================================================
# # of modules to be pruned: 20
# % of each module pruned: 0.3
# num_similar_params: 290825
# float(len(preprune)): 415464.0
# new model size (MB): 602.5403037702816 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.007101748751286718
# Accuracy: 1.0
# Runtime: 2.060485363006592
# [('pruning_type', 'global_L1unstructured'), ('num_params', 20), ('percentage_pruned', 0.3), ('accuracy', 1.0), ('runtime', 2.060485363006592), ('num_videos', 20), ('num_similar_params', 290825), ('total_possible_selected_paramters', 415464.0), ('new_model_size_mb', 602.5403037702816), ('percentage_of_size_saved', 0.007101748751286718), ('efficientnet._blocks.0._bn1_bias', 1), ('efficientnet._blocks.4._se_expand_weight', 1), ('efficientnet._blocks.5._depthwise_conv_weight', 1), ('efficientnet._blocks.7._bn2_bias', 1), ('efficientnet._blocks.9._project_conv_weight', 1), ('efficientnet._blocks.13._se_reduce_weight', 1), ('efficientnet._blocks.13._project_conv_weight', 1), ('efficientnet._blocks.14._expand_conv_weight', 1), ('efficientnet._blocks.14._se_expand_weight', 1), ('efficientnet._blocks.15._expand_conv_weight', 1), ('efficientnet._blocks.15._depthwise_conv_weight', 1), ('efficientnet._blocks.15._se_expand_bias', 1), ('efficientnet._blocks.20._bn0_weight', 1), ('efficientnet._blocks.20._bn2_bias', 1), ('efficientnet._blocks.22._se_reduce_weight', 1), ('efficientnet._blocks.22._bn2_bias', 1), ('efficientnet._blocks.25._depthwise_conv_weight', 1), ('efficientnet._blocks.25._se_expand_bias', 1), ('efficientnet._blocks.28._depthwise_conv_weight', 1), ('efficientnet._blocks.31._se_reduce_bias', 1)]
# ==================================================
# # of modules to be pruned: 20
# % of each module pruned: 0.2
# num_similar_params: 2529670
# float(len(preprune)): 3162088.0
# new model size (MB): 584.982611219554 vs. old model size(MB): 606.85 MB
# percentage of size saved: 0.03603425686816521
# Accuracy: 1.0
# Runtime: 2.062574625015259
# [('pruning_type', 'global_L1unstructured'), ('num_params', 20), ('percentage_pruned', 0.2), ('accuracy', 1.0), ('runtime', 2.062574625015259), ('num_videos', 20), ('num_similar_params', 2529670), ('total_possible_selected_paramters', 3162088.0), ('new_model_size_mb', 584.982611219554), ('percentage_of_size_saved', 0.03603425686816521), ('efficientnet._blocks.3._bn0_bias', 1), ('efficientnet._blocks.3._bn2_bias', 1), ('efficientnet._blocks.7._bn2_bias', 1), ('efficientnet._blocks.11._se_expand_bias', 1), ('efficientnet._blocks.11._bn2_bias', 1), ('efficientnet._blocks.12._bn1_weight', 1), ('efficientnet._blocks.13._project_conv_weight', 1), ('efficientnet._blocks.15._se_reduce_weight', 1), ('efficientnet._blocks.16._depthwise_conv_weight', 1), ('efficientnet._blocks.16._bn2_bias', 1), ('efficientnet._blocks.19._bn0_bias', 1), ('efficientnet._blocks.20._bn2_bias', 1), ('efficientnet._blocks.23._bn1_weight', 1), ('efficientnet._blocks.23._se_reduce_weight', 1), ('efficientnet._blocks.25._se_expand_bias', 1), ('efficientnet._blocks.27._depthwise_conv_weight', 1), ('efficientnet._blocks.28._expand_conv_weight', 1), ('efficientnet._blocks.29._depthwise_conv_weight', 1), ('efficientnet._blocks.31._expand_conv_weight', 1), ('efficientnet._blocks.31._project_conv_weight', 1)]
# ==================================================
